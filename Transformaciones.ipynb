# %% [markdown]
# ## Importación de las librerías necesarias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Carga de datos y exploración de los respectivos dataframes

# %% [markdown]
# ### Dataframe `movies_dataset`

# %%
df_movie=pd.read_csv(r"Datasets/movies_dataset.csv",delimiter=",")

# %%
# Visualización de las doce primeras columnas
df_movie.iloc[:3,:12]
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
#
#      original_title                                           overview  \
# 0         Toy Story  Led by Woody, Andy's toys live happily in his ...
# ...

# %%
# Visualización de las últimas doce columnas
df_movie.iloc[:3,12:]
# Out:
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
#
#                                 production_countries release_date    revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  373554033
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  262797249
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22          0
#
#    runtime                                   spoken_languages    status  \
# 0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2    101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# ...

# %%
# Información del data frame
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45463 non-null  float64
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %% [markdown]
# * #### Observación: se procederá a eliminar las filas duplicadas en las cuales los valores de todas las columnas sean idénticos. Esto se realiza con el fin de garantizar la integridad y consistencia de los datos en los dataframes.

# %%
# Observando los valores duplicados
duplicates=df_movie[df_movie.duplicated(keep=False)].sort_values(by="id")
print(duplicates.shape[0])
duplicates.head(8)
# Out:
# 33
#        adult belongs_to_collection  budget  \
# 7345   False                   NaN       0
# 9165   False                   NaN       0
# 24843  False                   NaN       0
# 14012  False                   NaN       0
# 22150  False                   NaN       0
# 14000  False                   NaN       0
# 8068   False                   NaN       0
# 9327   False                   NaN       0
#
#                                                   genres  \
# 7345   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 9165   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 24843  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 14012  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 22150  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 14000  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 8068   [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 9327   [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
#
# ...

# %%
# Eliminando los duplicados
df_movie.drop_duplicates(inplace=True)
df_movie=df_movie.reset_index(drop=True)

# %% [markdown]
# ### Dataframe `credits`

# %%
df_credit=pd.read_csv(r"Datasets/credits.csv")
# Visualizandop el dataframe
df_credit
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
# Información del data frame
df_credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
# Observando los valores duplicados
duplicates=df_credit[df_credit.duplicated(keep=False)].sort_values(by="id")
print(duplicates.shape[0])
duplicates.head(8)
# Out:
# 73
#                                                     cast  \
# 25950  [{'cast_id': 12, 'character': 'The Creature', ...
# 25885  [{'cast_id': 12, 'character': 'The Creature', ...
# 9165   [{'cast_id': 11, 'character': 'Jef Costello', ...
# 7345   [{'cast_id': 11, 'character': 'Jef Costello', ...
# 25895  [{'cast_id': 11, 'character': 'Mike Gaucher / ...
# 25969  [{'cast_id': 11, 'character': 'Mike Gaucher / ...
# 25967  [{'cast_id': 1, 'character': 'Churchill', 'cre...
# 25893  [{'cast_id': 1, 'character': 'Churchill', 'cre...
#
#                                                     crew    id
# 25950  [{'credit_id': '52fe4380c3a36847f80590dd', 'de...  3057
# 25885  [{'credit_id': '52fe4380c3a36847f80590dd', 'de...  3057
# 9165   [{'credit_id': '52fe440ac3a36847f807ee01', 'de...  5511
# 7345   [{'credit_id': '52fe440ac3a36847f807ee01', 'de...  5511
# 25895  [{'credit_id': '52fe44b8c3a36847f80a6389', 'de...  8767
# 25969  [{'credit_id': '52fe44b8c3a36847f80a6389', 'de...  8767
# ...

# %%
# Eliminando los duplicados
df_credit.drop_duplicates(inplace=True)
df_credit=df_credit.reset_index(drop=True)

# %% [markdown]
# ## Transformaciones

# %% [markdown]
# #### 1) Desanidación de los campos anidados que se encuentran en forma de diccionarios

# %%
# Columnas en forma de diccionario
df_movie.iloc[:3,[1,3,12,13,17]]
# Out:
#                                belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                NaN
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
#
#                                 production_countries  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...
#
#                                     spoken_languages
# ...

# %% [markdown]
# * Columna `belongs_to_collection`

# %% [markdown]
# Este campo almacena las rutas relativas de las imágenes de las películas. Sin embargo, estos datos no son necesarios, ya que no se requieren en ninguna etapa del proyecto. Además, algunas de las rutas ya no son funcionales y solo hay un número reducido de valores no nulos (4491). Por lo tanto, solo se considerarán los valores de las claves `name`.

# %%
df_movie.belongs_to_collection[0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
# Conservando solo las claves 'name'
df_movie["belongs_to_collection"]=df_movie.belongs_to_collection.apply(lambda dic: eval(dic)["name"] if pd.notnull(dic) else dic)

# %% [markdown]
# * Columnas `genres`, `production_companies`, ``production_countries`` y `spoken_languages`

# %% [markdown]
# Se guardarán exclusivamente los valores de las claves ``name`` en una lista, ya que los ID no son necesarios. Al extraer únicamente los valores de la clave `name`, se simplifica y conserva la información más relevante y descriptiva de los campos correspondientes. Esta acción mejora la legibilidad, comprensión y utilidad de los datos en el contexto del análisis y la visualización de los datos.

# %%
print(df_movie.genres[0])
print(df_movie.production_companies[1])
print(df_movie.production_countries[6])
print(df_movie.spoken_languages[5])
# Out:
# [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
# [{'name': 'TriStar Pictures', 'id': 559}, {'name': 'Teitler Film', 'id': 2550}, {'name': 'Interscope Communications', 'id': 10201}]
# [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'es', 'name': 'Español'}]

# %%
# Función que extrae los valores de las claves 'name'
def name(string):
    return [dic["name"] for dic in eval(string)]

# %%
# Aplicando la función 'name'
df_movie["genres"]=df_movie.genres.apply(name)
df_movie["production_companies"]=df_movie.production_companies.apply(name)
df_movie["production_countries"]=df_movie.production_countries.apply(name)
df_movie["spoken_languages"]=df_movie.spoken_languages.apply(name)

# Visualizando los resultados
df_movie.loc[:7,["belongs_to_collection","genres","production_companies","production_countries","spoken_languages"]]
# Out:
#             belongs_to_collection                              genres  \
# 0            Toy Story Collection         [Animation, Comedy, Family]
# 1                             NaN        [Adventure, Fantasy, Family]
# 2       Grumpy Old Men Collection                   [Romance, Comedy]
# 3                             NaN            [Comedy, Drama, Romance]
# 4  Father of the Bride Collection                            [Comedy]
# 5                             NaN    [Action, Crime, Drama, Thriller]
# 6                             NaN                   [Comedy, Romance]
# 7                             NaN  [Action, Adventure, Drama, Family]
#
#                                 production_companies  \
# 0                          [Pixar Animation Studios]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                     [Warner Bros., Lancaster Gate]
# 3           [Twentieth Century Fox Film Corporation]
# 4       [Sandollar Productions, Touchstone Pictures]
# ...

# %% [markdown]
# * Columnas `cast` y `crew`

# %% [markdown]
# Se tomarán únicamente los nombres de los actores que se encuentren en las claves ``name`` y se incluirán del campo ``cast``. Asimismo, del campo `crew` se seleccionarán exclusivamente los nombres de los directores que estén en las claves ``name`` y tengan el valor ``Director`` en la clave ``job``. No se considerarán las demás claves y valores presentes en los diccionarios, ya que no son relevantes para las dos últimas funciones que se realizarán.

# %%
print(df_credit.cast[0])
print(df_credit.crew[0])
# Out:
# [{'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3a36847f8024f95', 'gender': 2, 'id': 31, 'name': 'Tom Hanks', 'order': 0, 'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'}, {'cast_id': 15, 'character': 'Buzz Lightyear (voice)', 'credit_id': '52fe4284c3a36847f8024f99', 'gender': 2, 'id': 12898, 'name': 'Tim Allen', 'order': 1, 'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'}, {'cast_id': 16, 'character': 'Mr. Potato Head (voice)', 'credit_id': '52fe4284c3a36847f8024f9d', 'gender': 2, 'id': 7167, 'name': 'Don Rickles', 'order': 2, 'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'}, {'cast_id': 17, 'character': 'Slinky Dog (voice)', 'credit_id': '52fe4284c3a36847f8024fa1', 'gender': 2, 'id': 12899, 'name': 'Jim Varney', 'order': 3, 'profile_path': '/eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg'}, {'cast_id': 18, 'character': 'Rex (voice)', 'credit_id': '52fe4284c3a36847f8024fa5', 'gender': 2, 'id': 12900, 'name': 'Wallace Shawn', 'order': 4, 'profile_path': '/oGE6JqPP2xH4
# ...

# %%
# Realizando las transformaciones antes mencionadas
df_credit["actor"]=df_credit.cast.apply(name)
df_credit["director"]=df_credit.crew.apply(lambda x: [dic["name"]  for dic in eval(x) if dic["job"]=="Director"])
#Visualizando los resultados
df_credit.head(5)
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
#
#                                                actor           director
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...    [John Lasseter]
# 1  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...     [Joe Johnston]
# ...

# %% [markdown]
# OBSERVACIÓN: Los campos ``actor`` y ``director`` se añadirán al dataframe ``df_movie`` utilizando el campo ``id``. De esta manera, todos los datos estarán completos y listos para ser utilizados en los endpoints.

# %%
df_movie=pd.merge(df_movie,df_credit[["id","actor","director"]],on="id",how="inner")
# Visualizando los resultados
df_movie.iloc[:5,-5:]
# Out:
#    video  vote_average  vote_count  \
# 0  False           7.7        5415
# 1  False           6.9        2413
# 2  False           6.5          92
# 3  False           6.1          34
# 4  False           5.7         173
#
#                                                actor           director
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...    [John Lasseter]
# 1  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...     [Joe Johnston]
# 2  [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...    [Howard Deutch]
# 3  [Whitney Houston, Angela Bassett, Loretta Devi...  [Forest Whitaker]
# 4  [Steve Martin, Diane Keaton, Martin Short, Kim...    [Charles Shyer]

# %% [markdown]
# #### 2) Imputación de los valores nulos de los campos ``revenue`` y ``budget`` por el número 0

# %% [markdown]
# No existen valores nulos en estos campos

# %%
print(df_movie[df_movie.revenue.isnull()].shape[0])
print(df_movie[df_movie.budget.isnull()].shape[0])
# Out:
# 0
# 0

# %% [markdown]
# #### 3) Eliminación de  los valores nulos del campo `release_date`

# %%
# Visualizando el porcentaje de valores nulos de la columna
f"{(df_movie[df_movie.release_date.isnull()].shape[0]/df_movie.shape[0])*100}%"
# Out:
# '0.18479408658922913%'

# %%
df_movie.dropna(subset="release_date",inplace=True)

# %% [markdown]
# #### 4) Conversión de las fechas al formato AAAA-mm-dd y creación de la columna ``release_year``

# %% [markdown]
# El único campo de fecha disponible se encuentra en la columna ``release_date``, el cual se convertirá al tipo 'date'. A partir de este campo, se extraerá el año de estreno de cada película.

# %%
df_movie["release_date"]=pd.to_datetime(df_movie.release_date)
df_movie["release_year"]=df_movie.release_date.dt.year

# Visualizando los resultados
df_movie.loc[:,["release_date","release_year"]]
# Out:
#       release_date  release_year
# 0       1995-10-30          1995
# 1       1995-12-15          1995
# 2       1995-12-22          1995
# 3       1995-12-22          1995
# 4       1995-02-10          1995
# ...            ...           ...
# 45450   1991-05-13          1991
# 45452   2011-11-17          2011
# 45453   2003-08-01          2003
# 45454   1917-10-21          1917
# 45455   2017-06-09          2017
#
# [45372 rows x 2 columns]

# %% [markdown]
# #### 5) Creación de la columna ``return``: ``revenue`` / ``budget``

# %% [markdown]
# * Observación: Si el campo ``budget`` es igual a cero, el valor de ``return`` será establecido como cero, ya que la división por cero no está definida y no es posible realizarla.

# %%
# La mayoría de películas tienen un presupuesto (budget) de cero
f"{(df_movie[df_movie.budget==0].budget.shape[0]/df_movie.shape[0])*100}%"
# Out:
# '80.40201005025126%'

# %%
# Creando la columna 'return'
df_movie["return"]=df_movie.apply(lambda x: round(x.revenue/x.budget,2) if x.budget!=0 else 0,axis=1)
df_movie["return"]
# Out:
# 0        12.45
# 1         4.04
# 2         0.00
# 3         5.09
# 4         0.00
#          ...
# 45450     0.00
# 45452     0.00
# 45453     0.00
# 45454     0.00
# 45455     0.00
# Name: return, Length: 45372, dtype: float64

# %% [markdown]
# #### 6) Eliminación de las columnas que no serán utilizadas: ``video``, ``imdb_id``, ``adult``, ``original_title``, ``poster_path`` y ``homepage``.

# %%
df_movie.drop(columns=["video","imdb_id","adult","original_title","poster_path","homepage"],inplace=True)

# %% [markdown]
# * Visualizando el data frame resultante

# %%
df_movie
# Out:
#                 belongs_to_collection    budget                        genres  \
# 0                Toy Story Collection  30000000   [Animation, Comedy, Family]
# 1                                 NaN  65000000  [Adventure, Fantasy, Family]
# 2           Grumpy Old Men Collection         0             [Romance, Comedy]
# 3                                 NaN  16000000      [Comedy, Drama, Romance]
# 4      Father of the Bride Collection         0                      [Comedy]
# ...                               ...       ...                           ...
# 45450                             NaN         0      [Drama, Action, Romance]
# 45452                             NaN         0                       [Drama]
# 45453                             NaN         0     [Action, Drama, Thriller]
# 45454                             NaN         0                            []
# 45455                             NaN         0                            []
#
# ...

# %%
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45372 entries, 0 to 45455
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4489 non-null   object
#  1   budget                 45372 non-null  int64
#  2   genres                 45372 non-null  object
#  3   id                     45372 non-null  int64
#  4   original_language      45361 non-null  object
#  5   overview               44431 non-null  object
#  6   popularity             45372 non-null  float64
#  7   production_companies   45372 non-null  object
#  8   production_countries   45372 non-null  object
#  9   release_date           45372 non-null  datetime64[ns]
#  10  revenue                45372 non-null  int64
#  11  runtime                45126 non-null  float64
#  12  spoken_languages       45372 non-null  object
#  13  status                 45292 non-null  object
# ...

# %% [markdown]
# ### Exportación del data frame "df_platform" en un archivo CSV para la realización de los endpoints

# %%
df_movie.to_csv("movie_transformation.csv",index=False)

# %% [markdown]
# ---
